# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv('data_cancer.csv')

# %%
dataset.head()
# Out:
#    epatient_id  clump_thickness  cell_size_uniformity  cell_shape_uniformity  \
# 0      1000025              5.0                   1.0                      1
# 1      1002945              5.0                   4.0                      4
# 2      1015425              3.0                   1.0                      1
# 3      1016277              6.0                   8.0                      8
# 4      1017023              4.0                   1.0                      1
#
#    marginal_adhesion  single_ep_cell_size bare_nuclei  bland_chromatin  \
# 0                  1                    2           1              3.0
# 1                  5                    7          10              3.0
# 2                  1                    2           2              3.0
# 3                  1                    3           4              3.0
# 4                  3                    2           1              3.0
#
#    normal_nucleoli  mitoses   class doctor_name
# ...

# %%
dataset[['bare_nuclei','marginal_adhesion']]
# Out:
#     bare_nuclei  marginal_adhesion
# 0             1                  1
# 1            10                  5
# 2             2                  1
# 3             4                  1
# 4             1                  3
# ..          ...                ...
# 694           2                  1
# 695           1                  1
# 696           3                  3
# 697           4                  4
# 698           5                  5
#
# [699 rows x 2 columns]

# %%
dataset.iloc[:5]
# Out:
#    epatient_id  clump_thickness  cell_size_uniformity  cell_shape_uniformity  \
# 0      1000025              5.0                   1.0                      1
# 1      1002945              5.0                   4.0                      4
# 2      1015425              3.0                   1.0                      1
# 3      1016277              6.0                   8.0                      8
# 4      1017023              4.0                   1.0                      1
#
#    marginal_adhesion  single_ep_cell_size bare_nuclei  bland_chromatin  \
# 0                  1                    2           1              3.0
# 1                  5                    7          10              3.0
# 2                  1                    2           2              3.0
# 3                  1                    3           4              3.0
# 4                  3                    2           1              3.0
#
#    normal_nucleoli  mitoses   class doctor_name
# ...

# %%
dataset.info
# Out:
# <bound method DataFrame.info of      epatient_id  clump_thickness  cell_size_uniformity  \
# 0        1000025              5.0                   1.0
# 1        1002945              5.0                   4.0
# 2        1015425              3.0                   1.0
# 3        1016277              6.0                   8.0
# 4        1017023              4.0                   1.0
# ..           ...              ...                   ...
# 694       776715              3.0                   1.0
# 695       841769              2.0                   1.0
# 696       888820              5.0                  10.0
# 697       897471              4.0                   8.0
# 698       897471              4.0                   8.0
#
#      cell_shape_uniformity  marginal_adhesion  single_ep_cell_size  \
# 0                        1                  1                    2
# 1                        4                  5                    7
# ...

# %%
dataset.iloc[:5,:2]
# Out:
#    epatient_id  clump_thickness
# 0      1000025              5.0
# 1      1002945              5.0
# 2      1015425              3.0
# 3      1016277              6.0
# 4      1017023              4.0

# %%
df=dataset
df[df['clump_thickness']==5]
# Out:
#      epatient_id  clump_thickness  cell_size_uniformity  \
# 0        1000025              5.0                   1.0
# 1        1002945              5.0                   4.0
# 25       1065726              5.0                   2.0
# 27       1066979              5.0                   1.0
# 38       1084584              5.0                   4.0
# ..           ...              ...                   ...
# 677      1368267              5.0                   1.0
# 681      1371026              5.0                  10.0
# 682      1371920              5.0                   1.0
# 691       695091              5.0                  10.0
# 696       888820              5.0                  10.0
#
#      cell_shape_uniformity  marginal_adhesion  single_ep_cell_size  \
# 0                        1                  1                    2
# 1                        4                  5                    7
# 25                       3                  4                    2
# ...

# %%
df[df['class']=='malignant']
# Out:
#      epatient_id  clump_thickness  cell_size_uniformity  \
# 5        1017122              8.0                  10.0
# 12       1041801              NaN                   3.0
# 14       1044572              8.0                   7.0
# 15       1047630              7.0                   4.0
# 18       1050670             10.0                   7.0
# ..           ...              ...                   ...
# 681      1371026              5.0                  10.0
# 691       695091              5.0                  10.0
# 696       888820              5.0                  10.0
# 697       897471              4.0                   8.0
# 698       897471              4.0                   8.0
#
#      cell_shape_uniformity  marginal_adhesion  single_ep_cell_size  \
# 5                       10                  8                    7
# 12                       3                  3                    2
# 14                       5                  1                    7
# ...

# %%
#fazendo gráficos no próprio pandas

# %%
dataset.boxplot(column="mitoses",by="class")
# Out:
# <AxesSubplot:title={'center':'mitoses'}, xlabel='class'>
